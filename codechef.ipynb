# %%
import pandas as pd

# %%
dataset = pd.read_csv("data.csv", header=None)
dataset
# Out:
#             0     1    2
# 0    0.003959  1929  179
# 1    0.006699  1799  168
# 2    0.008831  1669  194
# 3    0.007917  1651  192
# 4    0.021620  1966   84
# ..        ...   ...  ...
# 537  0.756796  1455  -35
# 538  0.767870  1361    3
# 539  0.767151  1447  -32
# 540  0.710629  1460  -26
# 541  0.709478  1362   16
#
# [542 rows x 3 columns]

# %%
X = dataset.drop(columns=2)
y = dataset.drop(columns=[0, 1])

# %%
import numpy as np
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
X = np.array(X)
y = np.array(y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
mpl.rcParams['legend.fontsize'] = 12
fig = plt.figure()
ax = fig.gca(projection ='3d').scatter(X[:, 0], X[:, 1], y, label ='y', s = 5)
# ax = fig.gca(projection ='3d').scatter(X[:, 0], X[:, 1], lr.predict(X), label ='y', s = 5, color='red')

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset[0], dataset[2], color='black')
plt.scatter([X[i][0] for i in range(len(X))], lr.predict(X), color='red')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 3)
X_poly = poly.fit_transform(X)
poly.fit(X_poly, y)

lr2 = LinearRegression()
lr2.fit(X_poly, y)

# pred = lr2.predict(poly.fit_transform([[1, 1200]]))
# Out:
# LinearRegression()

# %%
mpl.rcParams['legend.fontsize'] = 12
fig = plt.figure()
ax = fig.gca(projection ='3d').scatter(X[:, 0], X[:, 1], y, label ='y', s = 5)
ax = fig.gca(projection ='3d').scatter(X[:, 0],
                                       X[:, 1], 
                                       lr2.predict(poly.fit_transform(X)), 
                                       label ='y', 
                                       s = 5, 
                                       color='red')

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset[0], dataset[2], color='black')
plt.scatter([X[i][0] for i in range(len(X))], lr2.predict(poly.fit_transform(X)), color='red')

# %%
pred = lr2.predict(poly.fit_transform([[45/3000, 2021]]))
pred
# Out:
# array([[133.97318136]])
